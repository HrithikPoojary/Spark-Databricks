# %%
file_df = spark.read.format("text")\
                .load(path = '/Volumes/dev/spark_db/datasets/spark_programming/data/apache-logs.txt')

file_df.display()

# single line read it single row

# %%
file_df.printSchema()
