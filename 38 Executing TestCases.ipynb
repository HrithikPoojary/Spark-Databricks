# %%
import pytest
import sys

sys.dont_write_bytecode = True

returncode = pytest.main(['.' , '-v' , '-p' , 'no:cacheprovider'])

assert returncode == 0 , "Pytest Failed"

# %%
# %load_ext autoreload
# %autoreload 2
