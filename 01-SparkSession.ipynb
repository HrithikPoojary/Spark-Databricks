# %%
from pyspark.sql import SparkSession 

spark_session = SparkSession.builder\
                    .getOrCreate()

# %%
#class method - version()
#class attribute - version

spark_session.version

# %%
spark.version

# %%
spark.sql('''select * from dev.spark_db.diamonds''').show(5 , truncate = False)

# %%
spark.table("dev.spark_db.diamonds").show(5 , truncate = False)

# %%
spark.sql("""select * from dev.spark_db.diamonds""").display(5)

# %%
help(display)
