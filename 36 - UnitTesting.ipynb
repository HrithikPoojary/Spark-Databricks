# %%
 schema = 'booked_by string , booking_date date , revenue double '

 df = spark.read.format("csv")\
                .option("header" , "true")\
                .schema(schema)\
                .load(path = '/Volumes/dev/spark_db/datasets/spark_programming/data/booking-summary.csv')

df.display()

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import dense_rank,col

df.withColumn("rank" , dense_rank().over(
                                                Window.partitionBy("booked_by")
                                                      .orderBy(col("revenue").desc_nulls_last())
                                                      .rowsBetween(Window.unboundedPreceding , Window.currentRow)
                                            )
              ).where("rank < 4").drop("rank").display()
